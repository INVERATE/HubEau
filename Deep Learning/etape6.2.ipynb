# %% [markdown]
# <a href="https://colab.research.google.com/github/INVERATE/HubEau/blob/master/Deep%20Learning/etape6.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.sparse import load_npz
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd


X_train = load_npz("X_train_tfidf.npz").toarray()
Y_train = pd.read_csv("y_train.csv")['y_train']
X_test = load_npz("X_test_tfidf.npz").toarray()
Y_test = pd.read_csv("y_test.csv")['y_test']

# Vérification de la dimension d'entrée
input_dim = X_train.shape[1]  # nombre de colonnes = nombre de features TF-IDF


model = Sequential()
model.add(Dense(64, input_shape=(input_dim,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


model.fit(X_train, Y_train, epochs=10, batch_size=10)


_, accuracy = model.evaluate(X_test, Y_test)
print('Accuracy: %.2f' % (accuracy * 100))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0925 - loss: -0.3478
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1045 - loss: -12.8185
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0908 - loss: -59.3896
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1144 - loss: -174.3521
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0900 - loss: -393.3321
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1241 - loss: -725.8835
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1003 - loss: -1268.6687
# Epoch 8/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1117 - loss: -1914.9833
# Epoch 9/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1054 - loss: -2828.2754
# Epoch 10/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0961 - loss: -4017.3496
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0662 - loss: -5288.5356
# Accuracy: 6.97

# %% [markdown]
# # 2 couches de 64 puis 32 neurones

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd
from scipy.sparse import load_npz
import numpy as np


# Encodage
X_train = load_npz("X_train_tfidf.npz").toarray()
Y_train = pd.read_csv("y_train.csv")['y_train']
X_test = load_npz("X_test_tfidf.npz").toarray()
Y_test = pd.read_csv("y_test.csv")['y_test']
Y_train_cat = to_categorical(Y_train - 1, num_classes=5)
Y_test_cat  = to_categorical(Y_test  - 1, num_classes=5)

input_dim = X_train.shape[1]

model = Sequential([
    Dense(64, input_shape=(input_dim,), activation='relu'),
    Dense(32, activation='relu'),
    Dense(5, activation='softmax')
])

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['categorical_accuracy']
)

model.fit(X_train, Y_train_cat, epochs=10, batch_size=32,
          validation_split=0.1)

_, accuracy = model.evaluate(X_test, Y_test_cat)
print(f'Multi-class accuracy: {accuracy:.2%}')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - categorical_accuracy: 0.6075 - loss: 1.5505 - val_categorical_accuracy: 0.6625 - val_loss: 1.3147
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.6359 - loss: 1.2370 - val_categorical_accuracy: 0.6625 - val_loss: 1.0920
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.6669 - loss: 0.9977 - val_categorical_accuracy: 0.6625 - val_loss: 1.0341
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.6526 - loss: 0.8901 - val_categorical_accuracy: 0.6625 - val_loss: 1.0011
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.6216 - loss: 0.7931 - val_categorical_accuracy: 0.6625 - val_loss: 0.9767
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6499 - loss: 0.6535 - val_categorical_accuracy: 0.6750 - val_loss: 0.9837
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - categorical_accuracy: 0.8345 - loss: 0.5004 - val_categorical_accuracy: 0.6750 - val_loss: 0.9914
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9515 - loss: 0.3779 - val_categorical_accuracy: 0.7000 - val_loss: 0.9933
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - categorical_accuracy: 0.9691 - loss: 0.2468 - val_categorical_accuracy: 0.7000 - val_loss: 1.0104
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.9972 - loss: 0.1692 - val_categorical_accuracy: 0.6875 - val_loss: 1.0730
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6834 - loss: 0.9825
# Multi-class accuracy: 68.66%

# %% [markdown]
# # Optimisation du modèle

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd
from scipy.sparse import load_npz
import numpy as np
from tensorflow.keras.optimizers import Adam, RMSprop, Adamax, Nadam, Lion


# Encodage
X_train = load_npz("X_train_tfidf.npz").toarray()
Y_train = pd.read_csv("y_train.csv")['y_train']
X_test = load_npz("X_test_tfidf.npz").toarray()
Y_test = pd.read_csv("y_test.csv")['y_test']
Y_train_cat = to_categorical(Y_train - 1, num_classes=5)
Y_test_cat  = to_categorical(Y_test  - 1, num_classes=5)

input_dim = X_train.shape[1]

model = Sequential([
    Dense(128, input_shape=(input_dim,), activation='relu'),
    Dense(64, activation='relu'),
    Dense(5, activation='softmax')
])

model.compile(
    loss='categorical_crossentropy',
    #optimizer=Adam(learning_rate=0.00099),
    optimizer=Nadam(learning_rate=0.0009),
    metrics=['categorical_accuracy']
)

model.fit(X_train, Y_train_cat, epochs=10, batch_size=32,
          validation_split=0.1)

_, accuracy = model.evaluate(X_test, Y_test_cat)
print(f'Multi-class accuracy: {accuracy:.2%}')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - categorical_accuracy: 0.5620 - loss: 1.5356 - val_categorical_accuracy: 0.6625 - val_loss: 1.1595
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - categorical_accuracy: 0.6170 - loss: 1.1431 - val_categorical_accuracy: 0.6625 - val_loss: 1.0296
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.6032 - loss: 1.0273 - val_categorical_accuracy: 0.6625 - val_loss: 0.9944
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.6558 - loss: 0.7445 - val_categorical_accuracy: 0.6750 - val_loss: 0.9735
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.7287 - loss: 0.6015 - val_categorical_accuracy: 0.6875 - val_loss: 0.9964
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - categorical_accuracy: 0.8915 - loss: 0.3790 - val_categorical_accuracy: 0.7125 - val_loss: 1.0066
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - categorical_accuracy: 0.9801 - loss: 0.2236 - val_categorical_accuracy: 0.6875 - val_loss: 1.0741
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.9942 - loss: 0.1310 - val_categorical_accuracy: 0.6875 - val_loss: 1.1325
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 1.0000 - loss: 0.0605 - val_categorical_accuracy: 0.6875 - val_loss: 1.2000
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 0.0357 - val_categorical_accuracy: 0.6875 - val_loss: 1.2269
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6844 - loss: 1.0683
# Multi-class accuracy: 69.15%

# %% [markdown]
# En ajoutant des couches (5 avec 128 --> 12) l'accuracy diminue (64%).
# En augmentant à 0.1 le learning rate l'accuracy diminue diminue aussi (51%) , avec O.5, 0.99, 0.00099 l'accuracy diminue moins (66%). 0.02 ---> 62%.
#
# Diminution du learning rate ! augmentation de l'accuarcy.
# 0.00099-->68.66%
# 0.0009-->69.14%
#
# La modification du learning rate ne change pas grand chose.
#
# Optimizer RMSprop, Nadam même résultat
# Nadam 0.0009 ---> 69.15% !!
# Adamax, Lion moins bien (66%, 62%)

# %% [markdown]
# # Etape 6

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import save_npz
import pickle

# Charger les données
df = pd.read_csv("Reviews_clean_lemmatized_short.csv")
texts = df['Text_without_stopwords']
y = df['Score']

X_train, X_test, y_train, y_test = train_test_split(texts, y, test_size=0.2, random_state=42)

# Sauvegarde
pd.DataFrame({'y_train': y_train}).to_csv('y_train.csv', index=False)
pd.DataFrame({'y_test': y_test}).to_csv('y_test.csv', index=False)
pd.DataFrame({'X_train': X_train}).to_csv('X_train.csv', index=False)
pd.DataFrame({'X_test': X_test}).to_csv('X_test.csv', index=False)

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
import pandas as pd
from scipy.sparse import load_npz
import numpy as np
from tensorflow.keras.optimizers import Adam, RMSprop, Adamax, Nadam, Lion


# Encodage
X_train = load_npz("X_train_tfidf.npz").toarray()
X_test = load_npz("X_test_tfidf.npz").toarray()

#X_train = pd.read_csv("X_train.csv")["X_train"]
Y_train = pd.read_csv("y_train.csv")['y_train']
#X_test = pd.read_csv("X_test.csv")["X_test"]
Y_test = pd.read_csv("y_test.csv")['y_test']
Y_train_cat = to_categorical(Y_train - 1, num_classes=5)
Y_test_cat  = to_categorical(Y_test  - 1, num_classes=5)

input_dim = X_train.shape[0]


model = Sequential([
    Embedding(1000, 64),
    GlobalAveragePooling1D(),
    Dense(128, input_shape=(input_dim,), activation='relu'),
    Dense(64, activation='relu'),
    Dense(5, activation='softmax')
])

model.compile(
    loss='categorical_crossentropy',
    #optimizer=Adam(learning_rate=0.00099),
    optimizer=Nadam(learning_rate=0.0009),
    metrics=['categorical_accuracy']
)

model.fit(X_train, Y_train_cat, epochs=10, batch_size=32,
          validation_split=0.1)

_, accuracy = model.evaluate(X_test, Y_test_cat)



print(f'Multi-class accuracy: {accuracy:.2%}')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - categorical_accuracy: 0.5185 - loss: 1.3316 - val_categorical_accuracy: 0.6625 - val_loss: 1.0563
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - categorical_accuracy: 0.6181 - loss: 1.1825 - val_categorical_accuracy: 0.6625 - val_loss: 1.0862
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - categorical_accuracy: 0.6274 - loss: 1.1647 - val_categorical_accuracy: 0.6625 - val_loss: 1.0523
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - categorical_accuracy: 0.6445 - loss: 1.1265 - val_categorical_accuracy: 0.6625 - val_loss: 1.0664
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - categorical_accuracy: 0.6396 - loss: 1.1354 - val_categorical_accuracy: 0.6625 - val_loss: 1.0624
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - categorical_accuracy: 0.6247 - loss: 1.1568 - val_categorical_accuracy: 0.6625 - val_loss: 1.0652
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - categorical_accuracy: 0.6188 - loss: 1.1728 - val_categorical_accuracy: 0.6625 - val_loss: 1.0637
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - categorical_accuracy: 0.6201 - loss: 1.1562 - val_categorical_accuracy: 0.6625 - val_loss: 1.0697
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - categorical_accuracy: 0.6334 - loss: 1.1452 - val_categorical_accuracy: 0.6625 - val_loss: 1.0607
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - categorical_accuracy: 0.6392 - loss: 1.1417 - val_categorical_accuracy: 0.6625 - val_loss: 1.0642
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.6494 - loss: 1.1170
# Multi-class accuracy: 66.67%

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
import pandas as pd
from scipy.sparse import load_npz
import numpy as np
from tensorflow.keras.optimizers import Adam, RMSprop, Adamax, Nadam, Lion
import tensorflow as tf
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Let's assume you have a vocabulary of 10,000 words, and you want to create 64-dimensional embeddings.
vocab_size = 10000
embedding_dim = 64

# Initialize the Embedding layer
embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=100)

text = pd.read_csv("Reviews_clean_lemmatized_short.csv")["Text_without_stopwords"]

# Initialize a tokenizer
tokenizer = Tokenizer()

# Fit the tokenizer on the text
tokenizer.fit_on_texts(text)

# Convert text to sequences of indices
sequences = tokenizer.texts_to_sequences(text)

# Pad sequences to ensure uniform length
padded_sequences = pad_sequences(sequences)

print("Word Index:", tokenizer.word_index)
print("Tokenized Sequences:", sequences)
print("Padded Sequences:", padded_sequences)

# Now let's apply this embedding layer to some sample data (for example, a batch of tokenized sentences)
# Your input data might look like this (padded sequences of word indices):
#sample_data = tf.constant(padded_sequences)

# Get the embeddings for the sample data
output = embedding_layer(padded_sequences)

print(output.shape)  # (batch_size, input_length, embedding_dim)

# Encodage
X_train = pd.read_csv("X_train.csv")["X_train"]
Y_train = pd.read_csv("y_train.csv")['y_train']
X_test = pd.read_csv("X_test.csv")["X_test"]
Y_test = pd.read_csv("y_test.csv")['y_test']
Y_train_cat = to_categorical(Y_train - 1, num_classes=5)
Y_test_cat  = to_categorical(Y_test  - 1, num_classes=5)

input_dim = X_train.shape[0]


model = Sequential([
    embedding_layer(padded_sequences),
    GlobalAveragePooling1D(),
    Dense(128, input_shape=(input_dim,), activation='relu'),
    Dense(64, activation='relu'),
    Dense(5, activation='softmax')
])

model.compile(
    loss='categorical_crossentropy',
, 1304, 2673, 24, 13, 369, 139, 24, 2, 996], [2, 37, 1305, 14, 2674, 121, 2, 381, 14, 382, 35, 34, 126, 2, 47, 200, 4, 63, 51], [672, 348, 1905, 102, 90, 9, 2675, 2676, 79, 997, 490, 1146, 28, 7, 1, 183, 1906, 2677, 9, 1, 998, 457, 84, 3, 2678, 7, 1, 999, 247, 1, 247, 4, 2679, 9, 2680, 3, 897, 2681, 13, 69, 334, 627, 898, 231, 274, 673, 1545, 627, 898, 2, 19, 34, 2, 171, 5, 9, 3, 297, 1000, 77, 4, 17, 114, 5, 6, 174, 5, 9, 1, 899, 1306, 6, 1, 1907, 900, 7, 1307, 1, 218, 627, 898, 119, 90, 1308, 147, 2682, 1908, 2683, 1309, 475, 458, 454, 1546, 2684, 4, 90, 79, 997, 490, 1146, 8, 1307, 2685, 898, 383, 3, 1907, 541, 1307, 21, 2686, 1547, 2687, 8, 33, 4, 1001, 380, 12], [4, 558, 37, 303, 4, 121, 29, 3, 901, 65, 2, 4, 255, 2688, 1310, 6, 40, 6, 3, 81, 24, 8, 4, 175, 10, 52], [3 ...
# Padded Sequences: [[   0    0    0 ...   23   48  150]
#  [   0    0    0 ...   33    3 1876]
#  [   0    0    0 ...    6    1 1880]
#  ...
#  [   0    0    0 ... 4976   20    5]
#  [   0    0    0 ... 4982 2538  561]
#  [   0    0    0 ...  542   32    6]]
# (1001, 771, 64)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2ecac4a3623f> in <cell line: 0>()
#      56
#      57
# ---> 58 model = Sequential([
#      59     embedding_layer(padded_sequences),
#      60     GlobalAveragePooling1D(),
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      73         if layers:
#      74             for layer in layers:
# ---> 75                 self.add(layer, rebuild=False)
#      76             self._maybe_rebuild()
#      77
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in add(self, layer, rebuild)
#      95                 layer = origin_layer
#      96         if not isinstance(layer, Layer):
# ---> 97             raise ValueError(
#      98                 "Only instances of `keras.Layer` can be "
#      99                 f"added to a Sequential model. Received: {layer} "
#
# ValueError: Only instances of `keras.Layer` can be added to a Sequential model. Received: [[[-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   ...
#   [-4.8795559e-02  1.8242601e-02  4.4225942e-02 ... -4.4224273e-02
#     3.7850704e-02  8.9767948e-03]
#   [-3.6871385e-02 -3.2262385e-02 -6.2593333e-03 ... -3.8793780e-02
#    -6.6780820e-03 -8.6056478e-03]
#   [-1.4549803e-02 -2.2192229e-02  8.3540455e-03 ...  1.5728090e-02
#     1.4332201e-02 -3.9613020e-02]]
#
#  [[-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   ...
#   [-1.1654019e-02  2.9742491e-02  3.4909453e-02 ...  1.0185730e-02
#    -2.5001943e-02  3.7459638e-02]
#   [ 2.0491567e-02 -3.2546364e-02 -7.9779141e-03 ...  1.3978966e-03
#     4.8093382e-02 -7.3186159e-03]
#   [-2.1955157e-02  2.6675787e-02  4.1718196e-02 ... -1.3972402e-02
#     8.4084384e-03 -1.1212181e-02]]
#
#  [[-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   ...
#   [-2.8999079e-02  2.0938125e-02  1.2643468e-02 ... -1.7927300e-02
#    -2.1099364e-02 -3.4346402e-02]
#   [-1.5680194e-02  4.6524238e-02  4.8749931e-03 ... -1.6510487e-05
#    -1.2909759e-02 -4.3123569e-02]
#   [ 2.6949394e-02  2.5494192e-02 -2.1575188e-02 ... -3.7137199e-02
#     9.2990287e-03 -4.8771203e-02]]
#
#  ...
#
#  [[-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   ...
#   [-4.4944383e-02  4.2439584e-02 -4.6202660e-02 ... -3.1402290e-02
#     4.9282502e-02  3.4834411e-02]
#   [ 3.1486992e-02  2.8777447e-02  1.7507840e-02 ... -3.7346266e-02
#    -3.1562794e-02 -1.8292975e-02]
#   [ 3.4528341e-02 -4.9780037e-02  8.5843317e-03 ... -7.5349808e-03
#     6.1257705e-03 -3.4339800e-03]]
#
#  [[-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   ...
#   [ 4.1456427e-02  2.4323259e-02  1.7372739e-02 ... -2.6504159e-02
#     3.8739014e-02  2.9737625e-02]
#   [-1.6957998e-02 -3.9410781e-02  4.9979720e-02 ...  3.6006797e-02
#     3.5261799e-02 -8.4536895e-03]
#   [-4.9357899e-03 -1.5428614e-02  3.4205917e-02 ...  3.5707023e-02
#     4.4350777e-02 -1.4206052e-02]]
#
#  [[-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   [-1.5337050e-02 -6.4236745e-03 -3.1764939e-02 ...  3.5604145e-02
#    -4.3289807e-02  3.6195640e-02]
#   ...
#   [-3.2116249e-02  2.8409552e-02  1.2461256e-02 ... -4.0967654e-02
#     1.8166576e-02 -1.3864495e-02]
#   [-5.4560676e-03 -2.4574006e-02 -4.0304292e-02 ...  2.5604773e-02
#     3.1390700e-02  3.5213742e-02]
#   [-2.8999079e-02  2.0938125e-02  1.2643468e-02 ... -1.7927300e-02
#    -2.1099364e-02 -3.4346402e-02]]] (of type <class 'tensorflow.python.framework.ops.EagerTensor'>)

# %%
# TensorFlow/Keras Implementation
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense

# Define the size of the vocabulary and the dimensionality of the embeddings
vocab_size = 10000
embedding_dim = 100

text = pd.read_csv("Reviews_clean_lemmatized_short.csv")["Text_without_stopwords"]

# Initialize a tokenizer
tokenizer = Tokenizer()

# Fit the tokenizer on the text
tokenizer.fit_on_texts(text)

# Convert text to sequences of indices
sequences = tokenizer.texts_to_sequences(text)

# Pad sequences to ensure uniform length
padded_sequences = pad_sequences(sequences)

print("Word Index:", tokenizer.word_index)
print("Tokenized Sequences:", sequences)
print("Padded Sequences:", padded_sequences)

# Now let's apply this embedding layer to some sample data (for example, a batch of tokenized sentences)
# Your input data might look like this (padded sequences of word indices):
#sample_data = tf.constant(padded_sequences)

# Get the embeddings for the sample data
output = embedding_layer(padded_sequences)

# Create a simple model with an Embedding layer
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=50))  # 50 is the length of input sequences
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()


model.fit(padded_sequences, Y_train_cat, epochs=10, batch_size=32,
          validation_split=0.1)

_, accuracy = model.evaluate(X_test, Y_test_cat)



print(f'Multi-class accuracy: {accuracy:.2%}')
# Out:
# Word Index: {'the': 1, 'i': 2, 'a': 3, 'be': 4, 'it': 5, 'to': 6, 'of': 7, 'this': 8, 'in': 9, 'for': 10, 'that': 11, 'you': 12, 'they': 13, 'with': 14, 'but': 15, 'do': 16, 'not': 17, "'s": 18, 'like': 19, "n't": 20, 'on': 21, 'taste': 22, 'good': 23, 'so': 24, 'flavor': 25, 'bag': 26, 'love': 27, 'one': 28, 'at': 29, 'or': 30, 'great': 31, 'use': 32, 'product': 33, 'all': 34, 'we': 35, 'food': 36, 'very': 37, 'buy': 38, 'if': 39, 'get': 40, 'just': 41, 'find': 42, 'have': 43, 'from': 44, 'tea': 45, 'when': 46
# Padded Sequences: [[   0    0    0 ...   23   48  150]
#  [   0    0    0 ...   33    3 1876]
#  [   0    0    0 ...    6    1 1880]
#  ...
#  [   0    0    0 ... 4976   20    5]
#  [   0    0    0 ... 4982 2538  561]
#  [   0    0    0 ...  542   32    6]]
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_22 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-4ee6648b03b0> in <cell line: 0>()
#      46
#      47
# ---> 48 model.fit(padded_sequences[:800], Y_train_cat, epochs=10, batch_size=32,
#      49           validation_split=0.1)
#      50
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py in binary_crossentropy(target, output, from_logits)
#     772     for e1, e2 in zip(target.shape, output.shape):
#     773         if e1 is not None and e2 is not None and e1 != e2:
# --> 774             raise ValueError(
#     775                 "Arguments `target` and `output` must have the same shape. "
#     776                 "Received: "
#
# ValueError: Arguments `target` and `output` must have the same shape. Received: target.shape=(None, 5), output.shape=(None, 1)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Nadam, Adam

# Charger les textes
text = pd.read_csv("Reviews_clean_lemmatized_medium.csv")["Text_without_stopwords"]

# Initialiser le tokenizer
vocab_size = 10000  # ajustable selon ton vocabulaire réel
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(text)

# Convertir les textes en séquences d’indices
sequences = tokenizer.texts_to_sequences(text)

# Padding des séquences
max_length = 100  # fixez une taille fixe
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')


Y_train = pd.read_csv("y_train.csv")['y_train']
Y_test = pd.read_csv("y_test.csv")['y_test']

Y_train_cat = to_categorical(Y_train - 1, num_classes=5)
Y_test_cat  = to_categorical(Y_test  - 1, num_classes=5)

X_train = padded_sequences[:len(Y_train_cat)]
X_test  = padded_sequences[len(Y_train_cat):len(Y_train_cat)+len(Y_test_cat)]

embedding_dim = 64

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(5, activation='softmax')
])

model.compile(
    loss='categorical_crossentropy',
    optimizer=Nadam(learning_rate=0.0009),
    metrics=['categorical_accuracy']
)


model.fit(X_train, Y_train_cat, epochs=10, batch_size=32, validation_split=0.1)

_, accuracy = model.evaluate(X_test, Y_test_cat)
print(f'Multi-class accuracy: {accuracy:.2%}')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - categorical_accuracy: 0.6172 - loss: 1.4822 - val_categorical_accuracy: 0.6625 - val_loss: 1.2023
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.6350 - loss: 1.2060 - val_categorical_accuracy: 0.6625 - val_loss: 1.1351
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6561 - loss: 1.1348 - val_categorical_accuracy: 0.6625 - val_loss: 1.0939
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6496 - loss: 1.1101 - val_categorical_accuracy: 0.6625 - val_loss: 1.0727
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - categorical_accuracy: 0.6231 - loss: 1.1492 - val_categorical_accuracy: 0.6625 - val_loss: 1.0558
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - categorical_accuracy: 0.6604 - loss: 1.0754 - val_categorical_accuracy: 0.6625 - val_loss: 1.0496
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.6306 - loss: 1.1257 - val_categorical_accuracy: 0.6625 - val_loss: 1.0484
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.6350 - loss: 1.0998 - val_categorical_accuracy: 0.6625 - val_loss: 1.0487
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.6418 - loss: 1.0748 - val_categorical_accuracy: 0.6625 - val_loss: 1.0461
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6358 - loss: 1.0691 - val_categorical_accuracy: 0.6625 - val_loss: 1.0458
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6494 - loss: 1.1111
# Multi-class accuracy: 66.67%

# %%
# code for Glove word embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

x = pd.read_csv("Reviews_clean_lemmatized_medium.csv")["Text_without_stopwords"]

# create the dict.
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x)

# number of unique words in dict.
print("Number of unique words in dictionary=",
      len(tokenizer.word_index))
print("Dictionary is = ", tokenizer.word_index)

# download glove and unzip it in Notebook.
#!wget http://nlp.stanford.edu/data/glove.6B.zip
#!unzip glove*.zip

# vocab: 'the': 1, mapping of words with
# integers in seq. 1,2,3..
# embedding: 1->dense vector
def embedding_for_vocab(filepath, word_index,
                        embedding_dim):
    vocab_size = len(word_index) + 1

    # Adding again 1 because of reserved 0 index
    embedding_matrix_vocab = np.zeros((vocab_size,
                                       embedding_dim))

    with open(filepath, encoding="utf8") as f:
        for line in f:
            word, *vector = line.split()
            if word in word_index:
                idx = word_index[word]
                embedding_matrix_vocab[idx] = np.array(
                    vector, dtype=np.float32)[:embedding_dim]

    return embedding_matrix_vocab


# matrix for vocab: word_index
embedding_dim = 50
embedding_matrix_vocab = embedding_for_vocab(
    'glove.6B.100d.txt', tokenizer.word_index,
  embedding_dim)

print("Dense vector for first word is => ",
      embedding_matrix_vocab[1])
# Out:
# Number of unique words in dictionary= 16177
# Dictionary is =  {'the': 1, 'i': 2, 'a': 3, 'be': 4, 'it': 5, 'to': 6, 'of': 7, 'this': 8, 'for': 9, 'in': 10, 'that': 11, 'but': 12, 'you': 13, 'with': 14, 'not': 15, 'do': 16, "'s": 17, 'they': 18, "n't": 19, 'like': 20, 'on': 21, 'taste': 22, 'good': 23, 'so': 24, 'coffee': 25, 'flavor': 26, 'product': 27, 'one': 28, 'or': 29, 'use': 30, 'just': 31, 'great': 32, 'love': 33, 'if': 34, 'at': 35, 'very': 36, 'all': 37, 'get': 38, 'buy': 39, 'we': 40, 'would': 41, 'from': 42, 'find': 43, 'more': 44, 'have': 45, 'when': 46, 'will': 47, 'me': 48, 'food': 49, 'than': 50, 'cup': 51, 'no': 52, 'other': 53, 'out': 54, 'really': 55, 'tea': 56, 'some': 57, 'amazon': 58, 'well': 59, 'only': 60, 'too': 61, 'drink': 62, 'up': 63, 'try': 64, 'about': 65, 'much': 66, 'order': 67, 'make': 68, 'there': 69, 'price': 70, 'an': 71, 'also': 72, 'best': 73, 'because': 74, 'little': 75, 'your': 76, 'what': 77, 'bag': 78, "'ve": 79, 'give': 80, 'which': 81, 'say': 82, 'think': 83, "'m": 84, 'mix': 85, 'even': 86, 'sugar': 87, 'by': 88, 'brand': 89, 'water': 90, 'store': 91, 'any': 92, 'now': 93, 'after': 94, 'want': 95, 'chocolate': 96, 'add': 97, 'first': 98, 'as': 99, 'look': 100, 'again': 101, 'box': 102, 'he': 103, 'she': 104, 'could': 105, 'purchase': 106, 'our': 107, '2': 108, 'recommend': 109, 'then': 110, 'their': 111, 'pack': 112, 'work': 113, 'k': 114, 'year': 115, 'sweet': 116, 'hot': 117, 'favorite': 118, 'know': 119, 'day': 120, 'free': 121, 'way': 122, 'over': 123, 'juice': 124, 'go': 125, '3': 126, 'thing': 127, 'still': 128, 'bit': 129, 'enjoy': 130, 'need': 131, '1': 132, 'milk': 133, 'small': 134, 'two': 135, 'dog': 136, 'ingredient': 137, 'nice': 138, 'easy': 139, 'delicious': 140, 'most': 141, 'eat': 142, 'her': 143, "'re": 144, 'keep': 145, 'cat': 146, 'bad': 147, 'strong': 148, 'review': 149, 'how': 150, 'come': 151, 'without': 152, 'high': 153, 'package': 154, 'something': 155, 'treat': 156, 'snack': 157, 'healthy': 158, 'before': 159, 'organic': 160, 'few': 161, 'never': 162, 'seem': 163, 'different': 164, 'every': 165, 'ca': 166, 'calorie': 167, '5': 168, 'quality': 169, 'into': 170, 'orange': 171, 'right': 172, '4': 173, 'ever': 174, 'regular': 175, 'lot': 176, 'perfect': 177, 'always': 178, 'put': 179, 'less': 180, 'same': 181, "'ll": 182, 'old': 183, 'bean': 184, 'enough': 185, 'however': 186, 'stuff': 187, 'natural': 188, 'size': 189, 'though': 190, 'problem': 191, 'fresh': 192, 'soda': 193, 'sure': 194, 'definitely': 195, "'d": 196, 'roast': 197, 'hard': 198, 'while': 199, 'those': 200, 'far': 201, 'blend': 202, 'back': 203, 'tasty': 204, 'see': 205, 'big': 206, 'off': 207, 'people': 208, 'green': 209, 'own': 210, 'down': 211, 'open': 212, 'pretty': 213, 'feel': 214, 'gluten': 215, 'last': 216, 'variety': 217, 'low': 218, 'item': 219, 'cups': 220, 'long': 221, 'vanilla': 222, 'local': 223, 'each': 224, 'happy': 225, 'potato': 226, 'excellent': 227, 'start': 228, 'new': 229, 'expect': 230, 'per': 231, 'com': 232, 'switch': 233, 'fruit': 234, 'his': 235, 'smell': 236, 'almost': 237, 'sauce': 238, 'may': 239, 'star': 240, 'dark': 241, '6': 242, 'case': 243, 'highly': 244, 'should': 245, 'another': 246, 'actually': 247, 'light': 248, 'anything': 249, 'brew': 250, 'wonderful': 251, 'cocoa': 252, 'large': 253, 'cheap': 254, 'quite': 255, 'keurig': 256, 'family': 257, 'expensive': 258, 'amount': 259, 'smooth': 260, 'baby': 261, 'receive': 262, 'chicken': 263, 'diet': 264, 'real': 265, 'bottle': 266, 'kind': 267, 'take': 268, 'can': 269, 'pancake': 270, '100': 271, 'help': 272, 'fat': 273, 'usually': 274, 'save': 275, "'": 276, 'grocery': 277, 'half': 278, 'company': 279, 'leave': 280, 'around': 281, 'bitter': 282, 'probably': 283, 'morning': 284, 'powder': 285, 'away': 286, 'kid': 287, 'texture': 288, '12': 289, 'arrive': 290, 'him': 291, 'ounce': 292, 'read': 293, 'cooky': 294, '8': 295, 'stick': 296, 'home': 297, 'bold': 298, 'why': 299, 'recipe': 300, 'instead': 301, 'friend': 302, 'husband': 303, 'contain': 304, 'top': 305 ...
# Dense vector for first word is =>  [-0.038194   -0.24487001  0.72812003 -0.39961001  0.083172    0.043953
#  -0.39140999  0.3344     -0.57545     0.087459    0.28786999 -0.06731
#   0.30906001 -0.26383999 -0.13231    -0.20757     0.33395001 -0.33848
#  -0.31742999 -0.48335999  0.1464     -0.37303999  0.34577     0.052041
#   0.44946    -0.46970999  0.02628    -0.54154998 -0.15518001 -0.14106999
#  -0.039722    0.28277001  0.14393     0.23464    -0.31020999  0.086173
#   0.20397     0.52623999  0.17163999 -0.082378   -0.71787    -0.41531
#   0.20334999 -0.12763     0.41367     0.55186999  0.57907999 -0.33476999
#  -0.36559001 -0.54856998]
